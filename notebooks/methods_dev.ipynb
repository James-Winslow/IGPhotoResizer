# %%
import sys
sys.path.insert(0, r"C:\Users\james\Projects\portfolio\IGPhotoResizer")

from src.methods import METHODS
print("Methods loaded:", list(METHODS.keys()))

from PIL import Image
test_img = Image.new("RGB", (1200, 800), color=(100, 150, 200))
result = METHODS["padding_resize"](test_img, 1080, 1080)
print("padding_resize output size:", result.size)
# Out:
# Methods loaded: ['simple_resize', 'padding_resize', 'seam_carving_resize']
#   [padding_resize] (1200, 800) -> (1080x1080)
#     Scale factor: 0.9000 -> (1200x800) => (1080x720)
#     Dominant color extracted: RGB(100, 148, 196)
#     Pasted at offset (0, 180)
# padding_resize output size: (1080, 1080)
